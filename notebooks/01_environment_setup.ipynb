# %% [markdown]
# This notebook installs required dependencies and mounts Google Drive (Colab).

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install segmentation-models-pytorch==0.3.3 --quiet
# !pip install pretrainedmodels --quiet
# !pip install efficientnet-pytorch --quiet
